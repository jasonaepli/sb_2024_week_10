# %% [markdown]
# # Exercise 01: Two Important Fourier Pairs
#
# In this exercise,
# you will get familiar
# with two extremely important Fourier transform pairs:
# \begin{align*}
#     \text{impulse train} &\Longleftrightarrow \text{impulse train}\\
#     \text{rectangle} &\Longleftrightarrow \text{sinc function}
# \end{align*}
#
# Let's install the necessary packages:

# %%
import sys
# !{sys.executable} -m pip install -U pip
# !{sys.executable} -m pip install -U scikit-learn numpy matplotlib ipywidgets ipympl
# Out:
# Requirement already satisfied: pip in /home/kevin/.pyenv/versions/3.10.13/envs/sb_weekly_10/lib/python3.10/site-packages (24.0)
# Requirement already satisfied: scikit-learn in /home/kevin/.pyenv/versions/3.10.13/envs/sb_weekly_10/lib/python3.10/site-packages (1.4.1.post1)
# Requirement already satisfied: numpy in /home/kevin/.pyenv/versions/3.10.13/envs/sb_weekly_10/lib/python3.10/site-packages (1.26.4)
# Requirement already satisfied: matplotlib in /home/kevin/.pyenv/versions/3.10.13/envs/sb_weekly_10/lib/python3.10/site-packages (3.8.3)
# Requirement already satisfied: ipywidgets in /home/kevin/.pyenv/versions/3.10.13/envs/sb_weekly_10/lib/python3.10/site-packages (8.1.2)
# Requirement already satisfied: ipympl in /home/kevin/.pyenv/versions/3.10.13/envs/sb_weekly_10/lib/python3.10/site-packages (0.9.3)
# Requirement already satisfied: scipy>=1.6.0 in /home/kevin/.pyenv/versions/3.10.13/envs/sb_weekly_10/lib/python3.10/site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/kevin/.pyenv/versions/3.10.13/envs/sb_weekly_10/lib/python3.10/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/kevin/.pyenv/versions/3.10.13/envs/sb_weekly_10/lib/python3.10/site-packages (from scikit-learn) (3.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/kevin/.pyenv/versions/3.10.13/envs/sb_weekly_10/lib/python3.10/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/kevin/.pyenv/versions/3.10.13/envs/sb_weekly_10/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/kevin/.pyenv/versions/3.10.13/envs/sb_weekly_10/lib/python3.10/site-packages (from matplotlib) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/kevin/.pyenv/versions/3.10.13/envs/sb_weekly_10/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/kevin/.pyenv/versions/3.10.13/envs/sb_weekly_10/lib/python3.10/site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in /home/kevin/.pyenv/versions/3.10.13/envs/sb_weekly_10/lib/python3.10/site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/kevin/.pyenv/versions/3.10.13/envs/sb_weekly_10/lib/python3.10/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/kevin/.pyenv/versions/3.10.13/envs/sb_weekly_10/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: comm>=0.1.3 in /home/kevin/.pyenv/versions/3.10.13/envs/sb_weekly_10/lib/python3.10/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /home/kevin/.pyenv/versions/3.10.13/envs/sb_weekly_10/lib/python3.10/site-packages (from ipywidgets) (8.22.2)
# Requirement already satisfied: traitlets>=4.3.1 in /home/kevin/.pyenv/versions/3.10.13/envs/sb_weekly_10/lib/python3.10/site-packages (from ipywidgets) (5.14.2)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in /home/kevin/.pyenv/versions/3.10.13/envs/sb_weekly_10/lib/python3.10/site-packages (from ipywidgets) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in /home/kevin/.pyenv/versions/3.10.13/envs/sb_weekly_10/lib/python3.10/site-packages (from ipywidgets) (3.0.10)
# Requirement already satisfied: ipython-genutils in /home/kevin/.pyenv/versions/3.10.13/envs/sb_weekly_10/lib/python3.10/site-packages (from ipympl) (0.2.0)
# Requirement already satisfied: decorator in /home/kevin/.pyenv/versions/3.10.13/envs/sb_weekly_10/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/kevin/.pyenv/versions/3.10.13/envs/sb_weekly_10/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/kevin/.pyenv/versions/3.10.13/envs/sb_weekly_10/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/kevin/.pyenv/versions/3.10.13/envs/sb_weekly_10/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /home/kevin/.pyenv/versions/3.10.13/envs/sb_weekly_10/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.17.2)
# Requirement already satisfied: stack-data in /home/kevin/.pyenv/versions/3.10.13/envs/sb_weekly_10/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: exceptiongroup in /home/kevin/.pyenv/versions/3.10.13/envs/sb_weekly_10/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: pexpect>4.3 in /home/kevin/.pyenv/versions/3.10.13/envs/sb_weekly_10/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: six>=1.5 in /home/kevin/.pyenv/versions/3.10.13/envs/sb_weekly_10/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/kevin/.pyenv/versions/3.10.13/envs/sb_weekly_10/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/kevin/.pyenv/versions/3.10.13/envs/sb_weekly_10/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/kevin/.pyenv/versions/3.10.13/envs/sb_weekly_10/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/kevin/.pyenv/versions/3.10.13/envs/sb_weekly_10/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/kevin/.pyenv/versions/3.10.13/envs/sb_weekly_10/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in /home/kevin/.pyenv/versions/3.10.13/envs/sb_weekly_10/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)

# %% [markdown]
# and import some modules:

# %%
# %matplotlib widget

import ipywidgets as widgets
import numpy as np
import scipy as sp
import sklearn
import matplotlib.pyplot as plt

# %% [markdown]
# The code below creates some plot widgets:

# %%
def create_impulse_train_plot():
    
    def generate_data (spacing__samp):
        res = sklearn.utils.Bunch()
        
        res.spacing__samp = spacing__samp
        res.N_samps       = 60

        res.impulses_t = np.zeros( (1, res.N_samps) )
        res.impulses_t[0, ::res.spacing__samp] = 1

        res.sample_numbers = np.linspace(0, res.N_samps-1, res.N_samps).reshape(1, res.N_samps);
        
        res.N_fft = res.N_samps
            
        res.impulses_f = res.spacing__samp*np.abs(np.fft.fft(res.impulses_t, res.N_fft))/res.N_fft

        res.freq_numbers = np.linspace(0, res.N_samps-1, res.N_samps).reshape(1, res.N_samps)/res.N_samps;
        
        return res

    slider_spacing__samp = widgets.IntSlider(min=1, max=6, step=1, value= 1, description="k", continuous_update=True)

    fig = plt.figure(figsize=(12,5))
    fig.canvas.toolbar_visible = False
    fig.canvas.resizable       = False
    
    ax_t = fig.add_subplot(1, 2, 1)
    ax_f = fig.add_subplot(1, 2, 2)

    def update_lines(dummy):
        res = generate_data(slider_spacing__samp.value)
        
        ax_t.clear()
        ax_f.clear()

        ax_t.set_xlim(0, res.N_fft-1)
        ax_t.set_ylim(0, +1.5)
        plt.sca(ax_t)
        plt.xlabel(r'sample number')
        plt.grid(visible=True, which='major', axis='y')

        line_impulse_t, = ax_t.plot(np.transpose(res.sample_numbers), np.transpose(res.impulses_t), color='b', marker='.', linewidth=0.0)
        ax_t.legend([line_impulse_t], ['impulse train'])
    
        line_impulse_f, = ax_f.plot(np.transpose(res.freq_numbers), np.transpose(res.impulses_f), color='b', marker='.', linewidth=0.0)
        ax_f.set_xlim(0, 1.0)
        ax_f.set_ylim(0, +1.5)
        plt.sca(ax_f)
        plt.xlabel(r'freq [normalized]')
        plt.grid(visible=True, which='major', axis='y')
        ax_f.legend([line_impulse_f], ['impulse train'])

        fig.canvas.draw_idle()

    update_lines('dummy')
        
    slider_spacing__samp.observe(update_lines, names='value')
    
    display(slider_spacing__samp)
    
create_impulse_train_plot()
# Out:
# IntSlider(value=1, description='k', max=6, min=1)
# Canvas(resizable=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', '…

# %% [markdown]
# The left plot (the "time" or "sample" domain)
# shows an impulse train
# with every $k^{th}$ sample set to 1.
#
# The right plot (the "frequency" domain)
# shows the Fourier transform
# of the samples on the left.

# %% [markdown]
# **Does increasing $k$ increase or decrease the frequency of pulses in the train on the left plot?**

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# Set $k = 5$.
#
# **How far apart are the pulses in the train on the right plot?**

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# Adjust $k$ and inspect the spacing of the pulses in the frequency domain.
#
# **Come up with a formula for the frequency domain spacing in terms of the time domain spacing.**

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# The following code creates another plot widget:

# %%
def create_rect_plot():
    
    def generate_data (width__samp):
        res = sklearn.utils.Bunch()
        
        res.width__samp = width__samp
        res.N_samps     = 60

        res.impulses_t = np.zeros( (1, res.N_samps) )
        res.impulses_t[0, 0:res.width__samp] = 1.0

        res.sample_numbers = np.linspace(0, res.N_samps-1, res.N_samps).reshape(1, res.N_samps);
        
        res.N_fft = 10*res.N_samps

        res.impulses_t_buf = np.zeros((1,res.N_fft));
        res.impulses_t_buf[0,0:res.impulses_t.size] = res.impulses_t
        
        res.impulses_f = np.abs(sp.fft.fft(res.impulses_t_buf, res.N_fft)).reshape(1, res.N_fft)

        res.freq_numbers = np.linspace(0, res.N_fft-1, res.N_fft).reshape(1, res.N_fft)/res.N_fft;
        
        return res

    slider_width__samp = widgets.IntSlider(min=1, max=30, step=1, value=5, description="w", continuous_update=True)

    fig = plt.figure(figsize=(12,5))
    fig.canvas.toolbar_visible = False
    fig.canvas.resizable       = False
    
    ax_t = fig.add_subplot(1, 2, 1)
    ax_f = fig.add_subplot(1, 2, 2)

    def update_lines(dummy):
        res = generate_data(slider_width__samp.value)
        
        ax_t.clear()
        ax_f.clear()

        ax_t.set_xlim(0, res.N_samps-1)
        ax_t.set_ylim(0, +1.5) #/res.width__samp)
        plt.sca(ax_t)
        plt.xlabel(r'sample number')
        plt.grid(visible=True, which='major', axis='y')

        line_rect_t = ax_t.plot(np.transpose(res.sample_numbers), np.transpose(res.impulses_t), color='b', marker='.', linewidth=0.0)
        #ax_t.legend([line_impulse_t], ['impulse train'])
    
        line_rect_f = ax_f.plot(np.transpose(res.freq_numbers), np.transpose(res.impulses_f), '-b')
        ax_f.set_xlim(0, 1.0)
        ax_f.set_ylim(0, 1.1*res.width__samp)
        plt.sca(ax_f)
        plt.xlabel(r'freq [normalized]')
        plt.grid(visible=True, which='major', axis='y')
        #ax_f.legend([line_impulse_f], ['impulse train'])

        fig.canvas.draw_idle()

    update_lines('dummy')
        
    slider_width__samp.observe(update_lines, names='value')
    
    display(slider_width__samp)
    
create_rect_plot()
# Out:
# IntSlider(value=5, description='w', max=30, min=1)
# Canvas(resizable=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', '…

# %% [markdown]
# The left plot shows a rectangle with width $w$.
#
# The right plot shows the Fourier transform of the waveform on the left.

# %% [markdown]
# While adjusting $w$,
# note the position of the first null
# (where the graph touches $y=0$)
# on the right.
#
# **Write a formula for the frequency of the first null in terms of $w$.**

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# Set $w=5$.
#
# Recall that the Fourier transform coefficient describes the correlation of a complex exponential with the input waveform.
#
# **In terms of the complex unit circle, explain why the frequencies 0.2, 0.4, 0.6, and 0.8 are nulls, while every other frequency is not.**

# %%
plt.close('all')
